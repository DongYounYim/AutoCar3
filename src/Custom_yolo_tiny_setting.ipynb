# %%
# 초기 darknet 소스코드 불러오기
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15530, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 15530 (delta 5), reused 13 (delta 4), pack-reused 15514
# Receiving objects: 100% (15530/15530), 14.22 MiB | 4.96 MiB/s, done.
# Resolving deltas: 100% (10417/10417), done.

# %%
# darknet 으로 이동
# %cd darknet
# Out:
# /home/soda/Project/python/notebook/src/darknet

# %%
# darknet 활성화 사전 세팅
# GPU=1로 빌드하면 GPU 사용하여 가속하기 위한 CUDA를 포함한다(/usr/local/cuda에 CUDA가 있어야 한다)
# CUDNN=1로 빌드하면 GPU 사용하여 벼림가속을 위한 cuDNN v5-v7를 포함한다(/usr/local/cudnn에 cuDNN이 있어야 한다) (x)
# CUDNN_HALF=1로 빌드하면 텐서코어에 대해(Titan V, Tesla V100, DGX-2 그리고 계승된것) 검출 3x, 벼림 2x 가속됨 (x)
# OPENCV=1로 빌드하면 OpenCV 3.x/2.4.x를 포함한다 - 동영상파일과 네트워크 카메라 또는 웹캠으로부터 동영상뭉치로 검출할수 있다
# LIBSO=1로 빌드하면 darknet.so 라이브러리를 만든다 그리고 이진 실행가능 파일은 uselib로 이 라이브러리를 사용한다.
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/' Makefile
# !sed -i 's/LIBSO=0/LIBSO=1/' Makefile

# %%
# darknet 활성
# in zsh kernel
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -fPIC -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
#              ^~
# ...

# %%
# 선택사항 (추천)
# 현재 작업 디렉토리 /content/darknet
# data 폴터 내의 labels 폴터를 제외하고 data 및 cfg 폴더를 정리
# 데에터 폴더에서 다른 모든 파일을 제거하고 드라이브의 yolov4-tiny 폴더의 cfg 구성파일이 있으므로 cfg 정리
# %cd data/
# !find -maxdepth 1 -type f -exec rm -rf {} \;
# %cd ..
# %rm -rf cfg/
# %mkdir cfg
# Out:
# /home/soda/Project/python/notebook/src/darknet/data
# /home/soda/Project/python/notebook/src/darknet

# %%
# %cd ..
# Out:
# /home/soda/Project/python/notebook/src

# %%
# data file transfer
# !cp ./yolov4-tiny-settings/obj.zip ./darknet

# %%
# !unzip ./darknet/obj.zip -d ./darknet/data/
# Out:
# Archive:  ./darknet/obj.zip
#   inflating: ./darknet/data/obj/1.jpg
#   inflating: ./darknet/data/obj/1.txt
#   inflating: ./darknet/data/obj/10.jpg
#   inflating: ./darknet/data/obj/10.txt
#   inflating: ./darknet/data/obj/100.jpg
#   inflating: ./darknet/data/obj/100.txt
#   inflating: ./darknet/data/obj/100_142_2023-07-04 01%3A15%3A17.42148.jpg
#   inflating: ./darknet/data/obj/100_142_2023-07-04 01%3A15%3A17.42148.txt
#   inflating: ./darknet/data/obj/100_148_2023-07-04 01%3A12%3A50.38297.jpg
#   inflating: ./darknet/data/obj/100_148_2023-07-04 01%3A12%3A50.38297.txt
#   inflating: ./darknet/data/obj/100_148_2023-07-04 01%3A28%3A00.51301.jpg
#   inflating: ./darknet/data/obj/100_148_2023-07-04 01%3A28%3A00.51301.txt
#   inflating: ./darknet/data/obj/1000.jpg
#   inflating: ./darknet/data/obj/1000.txt
#   inflating: ./darknet/data/obj/1001.jpg
#   inflating: ./darknet/data/obj/1001.txt
#   inflating: ./darknet/data/obj/1002.jpg
#   inflating: ./darknet/data/obj/1002.txt
# ...

# %%
# %cp ./yolov4-tiny-settings/yolov4-tiny-custom.cfg ./darknet/cfg

# %%
# setting file transfer
# %cp ./yolov4-tiny-settings/obj.names ./darknet/data
# %cp ./yolov4-tiny-settings/obj.data ./darknet/data

# %%
# train, test data file transfer
# %cp ./yolov4-tiny-settings/data/train.txt ./darknet/data
# %cp ./yolov4-tiny-settings/data/test.txt ./darknet/data
